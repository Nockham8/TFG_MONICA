# %% [markdown]
# # **Recorte de caras**
# ***

# %% [markdown]
# En este código se aplica la librería de Python 'face_recogition' para recortar los rostros de las imágenes, con tal de eliminar los fondos.

# %% [markdown]
# <a id="1"></a>
# ## 1. Carga de datos

# %% [markdown]
# Primero cargaremos las librerias.

# %%
# !pip install face_recognition
from PIL import Image, ImageDraw
import face_recognition
import pandas as pd
import cv2
from google.colab.patches import cv2_imshow
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566171 sha256=fe82a6745e33ba1ea378f554ab902d37a0621bcca6dee65e2d417e0f8e077acd
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %% [markdown]
# <a id="2"></a>
# ## 2. Ejecución face_recognition

# %% [markdown]
# Creamos un dataframe de la lista de txt de todas las imágenes que vamos a utilizar.

# %%
dt = pd.read_csv('/content/drive/My Drive/TFG/BLOQUE_1/CelebA/Img/nombres_de_imagenes.txt', sep=' ', header=None)
dt.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b333c122d29d> in <cell line: 2>()
#       1 #dt = pd.read_csv('/content/drive/MyDrive/data/celebA/identity_CelebA.txt', sep=' ')
# ----> 2 dt = pd.read_csv('/content/drive/My Drive/TFG/BLOQUE_1/list.txt', sep=' ', header=None)
#       3 dt.head()
#
# NameError: name 'pd' is not defined

# %%
dt.head()
# Out:
#             0
# 0  000001.jpg
# 1  000096.jpg
# 2  000116.jpg
# 3  000150.jpg
# 4  000404.jpg

# %% [markdown]
# Aplicamos face_recogition

# %%
show = False
for nom in dt[0]:        ## totes
#for nom in dt[0][:10]:  ## images de la 0 a la 9
  imageFR = face_recognition.load_image_file('/content/drive/My Drive/TFG/BLOQUE_1/CelebA/Img/main_img/'+nom)
  face_locations = face_recognition.face_locations(imageFR, number_of_times_to_upsample=0, model="cnn")
  if show:
    print("I found {} face(s) in this photograph.".format(len(face_locations)))
  image = cv2.imread('/content/drive/My Drive/TFG/BLOQUE_1/CelebA/Img/main_img/'+nom)
  pil_image = Image.fromarray(image)
  draw = ImageDraw.Draw(pil_image)
  for top, right, bottom, left in face_locations:
    crop_image = image[top:bottom, left:right]
    if show:
      cv2_imshow(image)
      cv2_imshow(crop_image)
    cv2.imwrite('/content/drive/My Drive/TFG/BLOQUE_1/CelebA/Img/cut_faces/'+nom, crop_image)
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d825da085bcc> in <cell line: 2>()
#       1 show = False
# ----> 2 for nom in dt[0]:        ## totes
#       3 #for nom in dt[0][:10]:  ## images de la 0 a la 9
#       4   imageFR = face_recognition.load_image_file('/content/drive/My Drive/data/celebA/main_img/'+nom)
#       5   face_locations = face_recognition.face_locations(imageFR, number_of_times_to_upsample=0, model="cnn")
#
# NameError: name 'dt' is not defined
